# %%
# !pip3 install --upgrade "https://github.com/fangwei123456/spikingjelly/tarball/master"

# %%
import torch
import sys
import os

# Add the src directory to the Python path
sys.path.append(os.path.abspath('.'))

from src.data import get_dataloaders
from src.train import train_model, test_single_sample
from src.config import LABEL_DICT

# Set device
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

# Create data loaders
train_loader, test_loader = get_dataloaders(
    root='',  # Empty string for current directory
    batch_size=64,
    num_workers=16
)

# Train the model
net = train_model(train_loader, test_loader, device)

# Test on a single sample
test_single_sample(net, test_loader.dataset, device)
